# %%
import pandas as pd
import numpy as np
import cv2
import json
import os
import matplotlib.pyplot as plt
import random
import seaborn as sns
from keras.models import Sequential
from keras import optimizers
from keras import backend as K
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

# %%
directory = "../input/face-mask-detection-dataset/Medical mask/Medical mask/Medical Mask/annotations"
image_directory = "../input/face-mask-detection-dataset/Medical mask/Medical mask/Medical Mask/images"
df = pd.read_csv("../input/face-mask-detection-dataset/train.csv")
df_test = pd.read_csv("../input/face-mask-detection-dataset/submission.csv")

# %% [markdown]
# Membaca network model dalam Caffe framework's format.

# %%
cvNet = cv2.dnn.readNetFromCaffe('../input/caffe-face-detector-opencv-pretrained-model/architecture.txt','../input/caffe-face-detector-opencv-pretrained-model/weights.caffemodel')

# %%
def getJSON(filePathandName):
    with open(filePathandName,'r') as f:
        return json.load(f)

# %%
def adjust_gamma(image, gamma=1.0):
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)])
    return cv2.LUT(image.astype(np.uint8), table.astype(np.uint8))

# %%
jsonfiles= []
for i in os.listdir(directory):
    jsonfiles.append(getJSON(os.path.join(directory,i)))
jsonfiles[0]
# Out:
# {'FileName': '3758.png',
#  'NumOfAnno': 2,
#  'Annotations': [{'isProtected': False,
#    'ID': 217843115901993120,
#    'BoundingBox': [112, 4, 455, 441],
#    'classname': 'face_with_mask',
#    'Confidence': 1,
#    'Attributes': {}},
#   {'isProtected': False,
#    'ID': 12530598208497002,
#    'BoundingBox': [113, 237, 345, 440],
#    'classname': 'mask_colorful',
#    'Confidence': 1,
#    'Attributes': {}}]}

# %%
df = pd.read_csv("../input/face-mask-detection-dataset/train.csv")
df.head()
# Out:
#        name   x1   x2   y1   y2       classname
# 0  2756.png   69  126  294  392  face_with_mask
# 1  2756.png  505   10  723  283  face_with_mask
# 2  2756.png   75  252  264  390   mask_colorful
# 3  2756.png  521  136  711  277   mask_colorful
# 4  6098.jpg  360   85  728  653    face_no_mask

# %% [markdown]
# yang dipakai hanya classname "face_with_mask" dan "face_no_mask"

# %%
data = []
img_size = 124
mask = ['face_with_mask']
non_mask = ["face_no_mask"]
labels={'mask':0,'without mask':1}
for i in df["name"].unique():
    f = i+".json"
    for j in getJSON(os.path.join(directory,f)).get("Annotations"):
        if j["classname"] in mask:
            x,y,w,h = j["BoundingBox"]
            img = cv2.imread(os.path.join(image_directory,i),1)
            img = img[y:h,x:w]
            img = cv2.resize(img,(img_size,img_size))
            data.append([img,labels["mask"]])
        if j["classname"] in non_mask:
            x,y,w,h = j["BoundingBox"]
            img = cv2.imread(os.path.join(image_directory,i),1)
            img = img[y:h,x:w]
            img = cv2.resize(img,(img_size,img_size))    
            data.append([img,labels["without mask"]])
random.shuffle(data)

# %%
len(data)
# Out:
# 5749

# %%
p = []
for face in data:
    if(face[1] == 0):
        p.append("Mask")
    else:
        p.append("No Mask")
sns.countplot(p)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:ylabel='count'>

# %%
X = []
Y = []
for features,label in data:
    X.append(features)
    Y.append(label)

# %%
X[0].shape
# Out:
# (124, 124, 3)

# %%
X = np.array(X)/255.0
X = X.reshape(-1,124,124,3)
Y = np.array(Y)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
Y.shape
# Out:
# (5749,)

# %% [markdown]
# # Model and Training

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding = "same", activation='relu', input_shape=(124,124,3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Out:
# 2022-12-19 14:41:09.118411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.119391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.258893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.259755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.260577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.261393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.263189: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 14:41:09.499892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.500775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.501541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.502302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.502982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:09.503715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.690388: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.691558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.692575: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.693569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.694573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.695526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-19 14:41:12.698801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-19 14:41:12.699869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 124, 124, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 122, 122, 64)      18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 120, 128)     73856
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 60, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 60, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 460800)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 460800)            0
# _________________________________________________________________
# dense (Dense)                (None, 50)                23040050
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 23,133,349
# Trainable params: 23,133,349
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam' ,metrics=['accuracy'])

# %%
xtrain,xval,ytrain,yval=train_test_split(X, Y,train_size=0.8,random_state=0)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,  
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False,    
        rotation_range=15,    
        width_shift_range=0.1,
        height_shift_range=0.1,  
        horizontal_flip=True,  
        vertical_flip=False)
datagen.fit(xtrain)

# %%
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=32),
                    steps_per_epoch=xtrain.shape[0]//32,
                    epochs=50,
                    verbose=1,
                    validation_data=(xval, yval))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-12-19 14:41:15.318214: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-12-19 14:41:17.304493: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 143/143 [==============================] - 34s 160ms/step - loss: 0.6534 - accuracy: 0.7259 - val_loss: 0.4403 - val_accuracy: 0.8948
# Epoch 2/50
# 143/143 [==============================] - 20s 141ms/step - loss: 0.4883 - accuracy: 0.8150 - val_loss: 0.3032 - val_accuracy: 0.8965
# Epoch 3/50
# 143/143 [==============================] - 20s 141ms/step - loss: 0.4799 - accuracy: 0.8051 - val_loss: 0.3177 - val_accuracy: 0.8557
# Epoch 4/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.4249 - accuracy: 0.8465 - val_loss: 0.2407 - val_accuracy: 0.9087
# Epoch 5/50
# 143/143 [==============================] - 20s 137ms/step - loss: 0.3935 - accuracy: 0.8485 - val_loss: 0.2617 - val_accuracy: 0.9043
# Epoch 6/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.3706 - accuracy: 0.8677 - val_loss: 0.2646 - val_accuracy: 0.8635
# Epoch 7/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.3424 - accuracy: 0.8785 - val_loss: 0.2027 - val_accuracy: 0.9217
# Epoch 8/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.3273 - accuracy: 0.8831 - val_loss: 0.2345 - val_accuracy: 0.8922
# Epoch 9/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.3379 - accuracy: 0.8761 - val_loss: 0.1968 - val_accuracy: 0.9235
# Epoch 10/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.3079 - accuracy: 0.8942 - val_loss: 0.2317 - val_accuracy: 0.9070
# Epoch 11/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.3034 - accuracy: 0.8923 - val_loss: 0.2064 - val_accuracy: 0.9261
# Epoch 12/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2992 - accuracy: 0.8921 - val_loss: 0.1888 - val_accuracy: 0.9270
# Epoch 13/50
# 143/143 [==============================] - 21s 143ms/step - loss: 0.3130 - accuracy: 0.8892 - val_loss: 0.1822 - val_accuracy: 0.9330
# Epoch 14/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.2927 - accuracy: 0.8916 - val_loss: 0.1857 - val_accuracy: 0.9270
# Epoch 15/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.2837 - accuracy: 0.8975 - val_loss: 0.1775 - val_accuracy: 0.9357
# Epoch 16/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.2767 - accuracy: 0.9028 - val_loss: 0.2042 - val_accuracy: 0.9104
# Epoch 17/50
# 143/143 [==============================] - 20s 143ms/step - loss: 0.2776 - accuracy: 0.8962 - val_loss: 0.1830 - val_accuracy: 0.9278
# Epoch 18/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2858 - accuracy: 0.8936 - val_loss: 0.2014 - val_accuracy: 0.9261
# Epoch 19/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.2837 - accuracy: 0.8918 - val_loss: 0.1825 - val_accuracy: 0.9330
# Epoch 20/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.2791 - accuracy: 0.8934 - val_loss: 0.2109 - val_accuracy: 0.9209
# Epoch 21/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2781 - accuracy: 0.9010 - val_loss: 0.1771 - val_accuracy: 0.9322
# Epoch 22/50
# 143/143 [==============================] - 21s 145ms/step - loss: 0.2713 - accuracy: 0.8984 - val_loss: 0.1715 - val_accuracy: 0.9365
# Epoch 23/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2681 - accuracy: 0.9010 - val_loss: 0.2204 - val_accuracy: 0.9035
# Epoch 24/50
# 143/143 [==============================] - 20s 141ms/step - loss: 0.2696 - accuracy: 0.8953 - val_loss: 0.1682 - val_accuracy: 0.9357
# Epoch 25/50
# 143/143 [==============================] - 20s 137ms/step - loss: 0.2663 - accuracy: 0.9006 - val_loss: 0.1684 - val_accuracy: 0.9330
# Epoch 26/50
# 143/143 [==============================] - 21s 145ms/step - loss: 0.2714 - accuracy: 0.8927 - val_loss: 0.1707 - val_accuracy: 0.9339
# Epoch 27/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.2653 - accuracy: 0.9015 - val_loss: 0.1685 - val_accuracy: 0.9391
# Epoch 28/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.2640 - accuracy: 0.9041 - val_loss: 0.1892 - val_accuracy: 0.9330
# Epoch 29/50
# 143/143 [==============================] - 20s 139ms/step - loss: 0.2748 - accuracy: 0.8988 - val_loss: 0.1686 - val_accuracy: 0.9365
# Epoch 30/50
# 143/143 [==============================] - 21s 143ms/step - loss: 0.2617 - accuracy: 0.9032 - val_loss: 0.1966 - val_accuracy: 0.9243
# Epoch 31/50
# 143/143 [==============================] - 20s 143ms/step - loss: 0.2613 - accuracy: 0.9026 - val_loss: 0.1753 - val_accuracy: 0.9339
# Epoch 32/50
# 143/143 [==============================] - 20s 139ms/step - loss: 0.2714 - accuracy: 0.8988 - val_loss: 0.1815 - val_accuracy: 0.9339
# Epoch 33/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.2511 - accuracy: 0.9008 - val_loss: 0.1899 - val_accuracy: 0.9330
# Epoch 34/50
# 143/143 [==============================] - 20s 142ms/step - loss: 0.2630 - accuracy: 0.8993 - val_loss: 0.1949 - val_accuracy: 0.9296
# Epoch 35/50
# 143/143 [==============================] - 20s 137ms/step - loss: 0.2583 - accuracy: 0.9032 - val_loss: 0.1933 - val_accuracy: 0.9139
# Epoch 36/50
# 143/143 [==============================] - 20s 143ms/step - loss: 0.2633 - accuracy: 0.8962 - val_loss: 0.2063 - val_accuracy: 0.9157
# Epoch 37/50
# 143/143 [==============================] - 20s 141ms/step - loss: 0.2586 - accuracy: 0.9021 - val_loss: 0.1770 - val_accuracy: 0.9374
# Epoch 38/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.2598 - accuracy: 0.9028 - val_loss: 0.1806 - val_accuracy: 0.9348
# Epoch 39/50
# 143/143 [==============================] - 21s 143ms/step - loss: 0.2507 - accuracy: 0.9067 - val_loss: 0.1793 - val_accuracy: 0.9409
# Epoch 40/50
# 143/143 [==============================] - 20s 137ms/step - loss: 0.2482 - accuracy: 0.9087 - val_loss: 0.1731 - val_accuracy: 0.9400
# Epoch 41/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.2398 - accuracy: 0.9144 - val_loss: 0.1751 - val_accuracy: 0.9417
# Epoch 42/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2459 - accuracy: 0.9083 - val_loss: 0.1856 - val_accuracy: 0.9287
# Epoch 43/50
# 143/143 [==============================] - 21s 144ms/step - loss: 0.2447 - accuracy: 0.9087 - val_loss: 0.1671 - val_accuracy: 0.9383
# Epoch 44/50
# 143/143 [==============================] - 20s 136ms/step - loss: 0.2540 - accuracy: 0.9028 - val_loss: 0.2031 - val_accuracy: 0.9157
# Epoch 45/50
# 143/143 [==============================] - 20s 139ms/step - loss: 0.2490 - accuracy: 0.9078 - val_loss: 0.1947 - val_accuracy: 0.9287
# Epoch 46/50
# 143/143 [==============================] - 20s 139ms/step - loss: 0.2440 - accuracy: 0.9091 - val_loss: 0.1701 - val_accuracy: 0.9365
# Epoch 47/50
# 143/143 [==============================] - 19s 133ms/step - loss: 0.2388 - accuracy: 0.9131 - val_loss: 0.1715 - val_accuracy: 0.9374
# Epoch 48/50
# 143/143 [==============================] - 20s 140ms/step - loss: 0.2520 - accuracy: 0.9080 - val_loss: 0.1838 - val_accuracy: 0.9313
# Epoch 49/50
# 143/143 [==============================] - 20s 141ms/step - loss: 0.2497 - accuracy: 0.9028 - val_loss: 0.1831 - val_accuracy: 0.9322
# Epoch 50/50
# 143/143 [==============================] - 20s 138ms/step - loss: 0.2506 - accuracy: 0.9076 - val_loss: 0.1915 - val_accuracy: 0.9235

# %% [markdown]
# ## Training and Validation Visualizations

# %%
plt.plot(history.history['accuracy'],'g')
plt.plot(history.history['val_accuracy'],'b')
plt.title('Training Accuracy vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'],'g')
plt.plot(history.history['val_loss'],'b')
plt.title('Training Loss vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
print(len(df_test["name"]),len(df_test["name"].unique()))
# Out:
# 8142 1698

# %%
test_images = ['0052.jpeg','1504.jpg', '0068.jpg','0012.jpg','0004.jpg','1374.jpg','0017.jpg','0025.jpg','0001.jpg']

# %%
gamma = 2.0
fig = plt.figure(figsize = (14,14))
rows = 3
cols = 3
axes = []
assign = {'0':'Mask','1':"No Mask"}
for j,im in enumerate(test_images):
    image =  cv2.imread(os.path.join(image_directory,im),1)
    image =  adjust_gamma(image, gamma=gamma)
    (h, w) = image.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300,300)), 1.0, (300, 300), (104.0, 177.0, 123.0))
    cvNet.setInput(blob)
    detections = cvNet.forward()
    for i in range(0, detections.shape[2]):
        try:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")
            frame = image[startY:endY, startX:endX]
            confidence = detections[0, 0, i, 2]
            if confidence > 0.19:
                im = cv2.resize(frame,(img_size,img_size))
                im = np.array(im)/255.0
                im = im.reshape(1,124,124,3)
                result = model.predict(im)
                if result>0.5:
                    label_Y = 1
                else:
                    label_Y = 0
                cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 2)
                cv2.putText(image,assign[str(label_Y)] , (startX, startY-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (36,255,12), 2)
        
        except:pass
    axes.append(fig.add_subplot(rows, cols, j+1))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Gamma Correction supaya gambar terlihat lebih terang
#
# blobFromImage membuat 4-dimensional blob dari gambar
#
# Confidence score threshold (0,19) untuk menentukan apakah hal yang dideteksi itu wajah atau bukan
#
# Deteksi yang melampaui confidence score kemudian diklasifikasikan ke mask atau non-mask image
